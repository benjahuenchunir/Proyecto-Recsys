# %% [markdown]
# # Content Based Recommender system

# %%
# In this recommender system the content of the movie 
# (overview, cast, crew, keyword, tagline etc) is used to find its similarity with other movies. 
# Then the movies that are most likely to be similar are recommended.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
animes = pd.read_csv('clean_data/animes.csv')

# %%
animes.head()
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/3/671...
# 2  https://cdn.myanimelist.net/images/anime/6/867...
# 3  https://cdn.myanimelist.net/images/anime/1223/...
# 4  https://cdn.myanimelist.net/images/anime/3/815...
#
#                                                 link
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...
# 4  https://myanimelist.net/anime/31758/Kizumonoga...

# %%
# drop duplicate titles
animes = animes.drop_duplicates(subset=['title'])

# %% [markdown]
# ### Plot description based Recommender

# %%
# We will compute pairwise similarity scores for all animes based on their plot descriptions and 
# recommend animes based on that similarity score. 
# The plot description is given in the overview feature of our dataset. Let's take a look at the data. ..

# %%
animes.synopsis.head()
# Out:
# 0    Following their participation at the Inter-Hig...
# 1    Music accompanies the path of the human metron...
# 2    The Abyss—a gaping chasm stretching down into ...
# 3    "In order for something to be obtained, someth...
# 4    After helping revive the legendary vampire Kis...
# Name: synopsis, dtype: object

# %%
# we need to convert the word vector for each description therefore we will TF-IDF VEctorizer

# %%
#Import TfIdfVectorizer from scikit-learn
from sklearn.feature_extraction.text import TfidfVectorizer

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Replace NaN with an empty string
animes['synopsis'] = animes['synopsis'].fillna('')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(animes['synopsis'])

#Output the shape of tfidf_matrix
tfidf_matrix.shape
# Out:
# (16214, 43912)

# %%
# Since we have used the TF-IDF vectorizer, 
# calculating the dot product will directly give us the cosine similarity score. 
# Therefore, we will use sklearn's linear_kernel() instead of cosine_similarities() since it is faster.

# %%
# Import linear_kernel
from sklearn.metrics.pairwise import linear_kernel

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
# We are going to define a function that takes in animes title as an input and outputs 
# a list of the 10 most similar animes. Firstly, for this, 
# we need a reverse mapping of anime titles and DataFrame indices. In other words, 
# we need a mechanism to identify the index of an anime in our metadata DataFrame, given its title

# %%
#Construct a reverse map of indices and movie titles
indices = pd.Series(animes.index, index=animes['title']).drop_duplicates()

# %%
# Function that takes in anime title as input and outputs most similar animes
def get_recommendations(name, cosine_sim=cosine_sim):
    # Get the index of the anime that matches the title
    idx = indices[name]

    # Get the pairwsie similarity scores of all animes with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the animes based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar animes
    sim_scores = sim_scores[1:11]

    # Get the anime indices
    anime_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar animes
    return animes['title'].iloc[anime_indices]

# %%
get_recommendations('Made in Abyss')
# Out:
# 905                   Pandora Hearts
# 383                    Tsumiki no Ie
# 3347            Mahoutsukai Precure!
# 13846                 Whistle! (ONA)
# 229         Jigoku Shoujo Futakomori
# 12985            Gundam Build Divers
# 6600     Gundam Build Divers Re:Rise
# 6247                       Plunderer
# 7770        Yasashii Fue, Tori, Ishi
# 9504                        Kokuhaku
# Name: title, dtype: object

# %% [markdown]
# # Metricas

# %%
df_train = pd.read_csv(
    "train", sep=",", names=["userid", "itemid", "rating"], header=None
)

df_train.rating = [1 if x >= 5 else 0 for x in df_train.rating]

df_train.head()
# Out:
#    userid   itemid  rating
# 0    2052  12445.0       1
# 1    5141  34599.0       1
# 2    3340  37510.0       1
# 3     588    853.0       1
# 4    4822  27775.0       1

# %%
df_test = pd.read_csv(
    "test", sep=",", names=["userid", "itemid", "rating"], header=None
)

df_test.head()
# Out:
#    userid   itemid  rating
# 0   18887  37450.0      10
# 1    8831  32379.0       2
# 2   37283  36882.0       9
# 3   35602  10490.0       9
# 4   39042      NaN       6

# %%
item_interaction_counts = df_train['itemid'].value_counts()
user_count = df_train['userid'].nunique()
item_popularity = (item_interaction_counts / user_count).to_dict()
metadata = animes[['uid', 'genre']]
item_categories: dict[int, set[str | None]] = {}
for row in metadata.itertuples():
    if isinstance(row.genre, str):
        genre_list = set(g.strip().replace("'", "") for g in row.genre[1:-1].split(','))
    else:
        genre_list: set = set()

    if isinstance(row.uid, int):
        item_categories[row.uid] = genre_list
    else:
        raise ValueError("Unexpected non-integer uid")
    # item_categories[int(row[1]) if row[1].is_integer() else row[1]] = set(map(lambda i: i.strip(), row[2].split(','))) if isinstance(row[2], str) else set()

# %%
user_items = {}
itemset = set()

for row in df_train.itertuples():
    if row[1] not in user_items:
        user_items[row[1]] = []

    user_items[row[1]].append(row[2])
    itemset.add(row[2])

itemset = np.sort(list(itemset))

# %%
user2row = {user_id: matrix_row for matrix_row, user_id in enumerate(user_items.keys())}
row2user = {matrix_row: user_id for user_id, matrix_row in user2row.items()}

uid_to_idx = pd.Series(range(len(animes)), index=animes['uid'])

# %%
print(uid_to_idx)
# Out:
# uid
# 28891        0
# 23273        1
# 34599        2
# 5114         3
# 31758        4
#          ...
# 10075    16209
# 35828    16210
# 10378    16211
# 33082    16212
# 16934    16213
# Length: 16214, dtype: int64

# %%
def recommend(user_id, n=10):
    """Recommend top-n anime titles for a user based on content similarity."""
    seen_items = user_items.get(user_id, [])
    
    N = cosine_sim.shape[0]
    scores = np.zeros(N, dtype=float)

    for item in seen_items:
        try:
            idx = uid_to_idx.get(item)
        except KeyError:
            continue

        row = cosine_sim[idx]
        try:
            import scipy.sparse as _sps
            if _sps.issparse(row):
                row = row.toarray()
        except Exception:
            pass

        row = np.asarray(row)
        if row.ndim == 2:
            row = row.sum(axis=0)
        row = row.ravel()
        if row.shape[0] == N:
            scores += row
        else:
            continue

    # Exclude items the user has already seen
    seen_idxs = []
    for item in seen_items:
        if item in uid_to_idx.index:
            idx = uid_to_idx.get(item)
            seen_idxs.append(idx)
    if seen_idxs:
        scores[seen_idxs] = -np.inf

    top_idxs = np.argsort(scores)[::-1][:n]

    return animes["uid"].iloc[top_idxs].values

# %%
user_items_test = {}

for row in df_test.itertuples():
    if row[1] not in user_items_test:
        user_items_test[row[1]] = []

    user_items_test[row[1]].append(row[2])

# %%
from evaluate import get_metrics

get_metrics(user_items_test, item_popularity, item_categories, recommend, k=10, delta=0.2)
# Out:
# Evaluando usuarios: 100%|██████████| 15582/15582 [00:17<00:00, 909.83it/s]
# --- Métricas Globales de Evaluación ---
# {
#   "mean_recall": 0.02041829138603332,
#   "mean_precision": 0.002190712513293159,
#   "mean_ap (MAP)": 0.009230741097100544,
#   "mean_ndcg": 0.011919163060023835,
#   "mean_novelty": 7.90006469565837,
#   "mean_diversity": 0.7831957567810762,
#   "num_users_evaluated": 14105
# }
#
# --- Reporte de Fairness (Disparidad de Grupo) ---
# {
#   "delta_threshold": 0.2,
#   "group_averages": {
#     "NaN": {
#       "recall (Cobertura)": 0.018231349538977367,
#       "precision (Tasa Aceptaci\u00f3n)": 0.0019488683989941325,
#       "MAP": 0.0086463364334278,
#       "NDCG": 0.01097533214882572,
#       "novelty": 7.811665045507173,
#       "diversity": 0.7867035437320433,
#       "count": 4772
#     },
#     "Female": {
#       "recall (Cobertura)": 0.015447154471544716,
#       "precision (Tasa Aceptaci\u00f3n)": 0.0015447154471544718,
#       "MAP": 0.007496612466124661,
#       "NDCG": 0.009379744564114372,
#       "novelty": 7.784328766506778,
#       "diversity": 0.7911373406403895,
#       "count": 2460
#     },
#     "Male": {
#       "recall (Cobertura)": 0.023978685612788632,
#       "precision (Tasa Aceptaci\u00f3n)": 0.002619893428063943,
#       "MAP": 0.010385477459189715,
#       "NDCG": 0.01364288607455869,
#       "novelty": 8.005153674546447,
#       "diversity": 0.7775396062536034,
#       "count": 6756
#     },
#     "Non-Binary": {
#       "recall (Cobertura)": 0.008547008547008548,
#       "precision (Tasa Aceptaci\u00f3n)": 0.0008547008547008547,
#       "MAP": 0.0028490028490028487,
#       "NDCG": 0.004273504273504274,
#       "novelty": 7.870768754346928,
#       "diversity": 0.7997555631031414,
#       "count": 117
#     }
#   },
#   "disparity_reports": [
#     {
#       "pair": [
#         "Male",
#         "Female"
#       ],
#       "recall_disparity": {
#         "value": 0.3557964468533574,
#         "bias": "True"
#       },
#       "precision_disparity": {
#         "value": 0.4103899683064626,
#         "bias": "True"
#       },
#       "map_disparity": {
#         "value": 0.27816390766982085,
#         "bias": "True"
#       },
#       "ndcg_disparity": {
#         "value": 0.3124809140196694,
#         "bias": "True"
#       },
#       "novelty_disparity": {
#         "value": 0.02758534277009743,
#         "bias": "False"
#       },
#       "diversity_disparity": {
#         "value": 0.017187577539671414,
#         "bias": "False"
#       }
#     }
#   ],
#   "category_disparity_report": {
#     "Male_vs_Female": {
#       "Mecha": {
#         "value": 0.21905665111604794,
#         "biased_toward": "Male"
#       },
#       "": {
#         "value": 0.16161111440017367,
#         "biased_toward": "Male"
#       },
#       "Supernatural": {
#         "value": 0.04012091100836679,
#         "biased_toward": "Female"
#       },
#       "Shoujo Ai": {
#         "value": 0.0011431312202725835,
#         "biased_toward": "Male"
#       },
#       "Josei": {
#         "value": 0.34256273396325965,
#         "biased_toward": "Female"
#       },
#       "Game": {
#         "value": 0.1825791483929677,
#         "biased_toward": "Male"
#       },
#       "Comedy": {
#         "value": 0.04078614951392215,
#         "biased_toward": "Female"
#       },
#       "Fantasy": {
#         "value": 0.05543285011124767,
#         "biased_toward": "Male"
#       },
#       "Cars": {
#         "value": 0.4681762077037667,
#         "biased_toward": "Male"
#       },
#       "Hentai": {
#         "value": 0.09949336020482469,
#         "biased_toward": "Female"
#       },
#       "Parody": {
#         "value": 0.055929784729643876,
#         "biased_toward": "Female"
#       },
#       "Samurai": {
#         "value": 0.08503600816530481,
#         "biased_toward": "Male"
#       },
#       "Harem": {
#         "value": 0.2013691551085155,
#         "biased_toward": "Male"
#       },
#       "Shoujo": {
#         "value": 0.43327701961077125,
#         "biased_toward": "Female"
#       },
#       "Psychological": {
#         "value": 0.012539991306313938,
#         "biased_toward": "Male"
#       },
#       "Yuri": {
#         "value": 0.2602451009413297,
#         "biased_toward": "Male"
#       },
#       "Romance": {
#         "value": 0.020031364598474134,
#         "biased_toward": "Male"
#       },
#       "Thriller": {
#         "value": 0.07183088728082217,
#         "biased_toward": "Male"
#       },
#       "Demons": {
#         "value": 0.38124537694815236,
#         "biased_toward": "Female"
#       },
#       "Kids": {
#         "value": 0.16020497361968955,
#         "biased_toward": "Female"
#       },
#       "Mystery": {
#         "value": 0.002959999106811353,
#         "biased_toward": "Male"
#       },
#       "Vampire": {
#         "value": 0.15742903337082859,
#         "biased_toward": "Male"
#       },
#       "Ecchi": {
#         "value": 0.1648682073513326,
#         "biased_toward": "Male"
#       },
#       "Magic": {
#         "value": 0.022320910970846465,
#         "biased_toward": "Male"
#       },
#       "Adventure": {
#         "value": 0.06725782864542755,
#         "biased_toward": "Male"
#       },
#       "Yaoi": {
#         "value": 0.40980063617156265,
#         "biased_toward": "Female"
#       },
#       "Martial Arts": {
#         "value": 0.1753614910285747,
#         "biased_toward": "Male"
#       },
#       "Military": {
#         "value": 0.11188552963605312,
#         "biased_toward": "Male"
#       },
#       "Police": {
#         "value": 0.04867408478795254,
#         "biased_toward": "Female"
#       },
#       "Shounen Ai": {
#         "value": 0.27158695605779276,
#         "biased_toward": "Female"
#       },
#       "Drama": {
#         "value": 0.021531565809131945,
#         "biased_toward": "Female"
#       },
#       "Historical": {
#         "value": 0.19589889290650553,
#         "biased_toward": "Female"
#       },
#       "School": {
#         "value": 0.02841455540591248,
#         "biased_toward": "Male"
#       },
#       "Sci-Fi": {
#         "value": 0.148997956465144,
#         "biased_toward": "Male"
#       },
#       "Slice of Life": {
#         "value": 0.0724385095883452,
#         "biased_toward": "Female"
#       },
#       "Seinen": {
#         "value": 0.017046863318256025,
#         "biased_toward": "Male"
#       },
#       "Super Power": {
#         "value": 0.09931498773496694,
#         "biased_toward": "Male"
#       },
#       "Music": {
#         "value": 0.09671252064134526,
#         "biased_toward": "Female"
#       },
#       "Dementia": {
#         "value": 0.28664790378096733,
#         "biased_toward": "Female"
#       },
#       "Horror": {
#         "value": 0.16226872330076517,
#         "biased_toward": "Female"
#       },
#       "Space": {
#         "value": 0.3396693495595732,
#         "biased_toward": "Male"
#       },
#       "Shounen": {
#         "value": 0.011413958795106007,
#         "biased_toward": "Female"
#       },
#       "Sports": {
#         "value": 0.1572841641093092,
#         "biased_toward": "Female"
#       },
#       "Action": {
#         "value": 0.11511650059167138,
#         "biased_toward": "Male"
#       }
#     }
#   }
# }
#
# Recall Global: 0.0204
# MAP Global: 0.0092
